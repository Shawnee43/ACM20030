# %%
import numpy as np 
import matplotlib.pyplot as plt

#Question1
def vec_length(x,y): 
    return"The length of the vector is",(np.sqrt(x**2 + y**2))

vec_length(5,6)
vec_length(-1,5)

print("sin(1) = %.3f" % np.sin(1.0))
# Out:
# sin(1) = 0.841

# %%
#Question2 
def IsPrime(n):
    if n == 1:
        return print("if the number is 1, it's neither prime nor composite") 
    i = 2
    while i <= np.sqrt(n):
        #for each i check if it divides n
        #needs an equal sign to check upto 3
        print(i)
        if (n % i == 0):
            return 0
        i += 1
        #if no divisors are found number is prime
    return 1
print(IsPrime(9))

count = 0
for i in range(1000):
    if IsPrime(i):
        count += 1
print("The number of prime numbers less than 1000 is,", count)


def PrimeCount(n):
    count2 = 0
    for i in range(n):
        if IsPrime(i):
            count2 += 1
        return count

print("The number of prime numbers less than 1000 is,", PrimeCount(1000))
print("The number of prime numbers less than 10000 is,", PrimeCount(10000)) #Fix code

x = np.arange(0,40,1)
Pi = np.zeros(40)
i = 0 
while i < np.size(Pi):
    Pi[i] = PrimeCount(i)
    i += 1

plt.plot(x, Pi, 'ro')
plt.xlabel('x')
plt.ylabel('Pi(x)')
plt.grid()
# Out:
# 2
# 3
# 0
# if the number is 1, it's neither prime nor composite
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 2
# 2
# 3
# 2
# 2
# 3
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 2
# 2
# 3
# 4
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 2
# 2
# 3
# 4
# 5
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 5
# 2
# 2
# 3
# 4
# 5
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 5
# 2
# 2
# 3
# 4
# 5
# 6
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 5
# 6
# 2
# 2
# 3
# 4
# 5
# 6
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 5
# 6
# 2
# 2
# 3
# 4
# 5
# 6
# 7
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 5
# 6
# 7
# 2
# 2
# 3
# 4
# 5
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 5
# 6
# 7
# 2
# 2
# 3
# 4
# 5
# 6
# 7
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 5
# 2
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 2
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 5
# 6
# 7
# 2
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 2
# 2
# 3
# 4
# 5
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 2
# 2
# 3
# 4
# 5
# 6
# 7
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 5
# 2
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 2
# ...

# %%
#Question3
z = np.loadtxt("Data.txt")
print(z)
x = z[:, 0]
y = z[:, 1]

ylog = np.log(y)
plt.plot(x, ylog)
plt.xlabel("x")
plt.ylabel("Log(y)")
plt.title("Log Scale")
plt.grid()

xlog = np.log(x)
plt.figure()
plt.plot(xlog, ylog)
plt.xlabel("Log(x)")
plt.ylabel("Log(y)")
plt.title("Log-Log Scale")
plt.grid()

#Data is representation of the power law as it bends on semi-log plot and is straight
#line on log-log plot. This is because as you take the logs of both axis' you "compress"
#them which essentially gets rid of any curvature.

#n=2
# Out:
# [[1.000e-01 1.000e-02]
#  [2.000e-01 4.000e-02]
#  [3.000e-01 9.000e-02]
#  [4.000e-01 1.600e-01]
#  [5.000e-01 2.500e-01]
#  [6.000e-01 3.600e-01]
#  [7.000e-01 4.900e-01]
#  [8.000e-01 6.400e-01]
#  [9.000e-01 8.100e-01]
#  [1.000e+00 1.000e+00]
#  [1.100e+00 1.210e+00]
#  [1.200e+00 1.440e+00]
#  [1.300e+00 1.690e+00]
#  [1.400e+00 1.960e+00]
#  [1.500e+00 2.250e+00]
#  [1.600e+00 2.560e+00]
#  [1.700e+00 2.890e+00]
#  [1.800e+00 3.240e+00]
#  [1.900e+00 3.610e+00]
#  [2.000e+00 4.000e+00]
#  [2.100e+00 4.410e+00]
#  [2.200e+00 4.840e+00]
#  [2.300e+00 5.290e+00]
#  [2.400e+00 5.760e+00]
#  [2.500e+00 6.250e+00]
#  [2.600e+00 6.760e+00]
#  [2.700e+00 7.290e+00]
#  [2.800e+00 7.840e+00]
#  [2.900e+00 8.410e+00]
#  [3.000e+00 9.000e+00]
#  [3.100e+00 9.610e+00]
#  [3.200e+00 1.024e+01]
#  [3.300e+00 1.089e+01]
#  [3.400e+00 1.156e+01]
#  [3.500e+00 1.225e+01]
#  [3.600e+00 1.296e+01]
#  [3.700e+00 1.369e+01]
#  [3.800e+00 1.444e+01]
#  [3.900e+00 1.521e+01]
#  [4.000e+00 1.600e+01]
# ...
